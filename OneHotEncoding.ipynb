# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
data=pd.read_csv(r"C:\Users\HP\Downloads\dataset.csv")
data.head()
# Out:
#   GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0      M   65        1               1        1              2
# 1      F   55        1               2        2              1
# 2      F   78        2               2        1              1
# 3      M   60        2               1        1              1
# 4      F   80        1               1        2              1
#
#    CHRONIC_DISEASE  FATIGUE  ALLERGY  WHEEZING  ALCOHOL_CONSUMING  COUGHING  \
# 0                2        1        2         2                  2         2
# 1                1        2        2         2                  1         1
# 2                1        2        1         2                  1         1
# 3                2        1        2         1                  1         2
# 4                1        2        1         2                  1         1
#
#    SHORTNESS_OF_BREATH  SWALLOWING_DIFFICULTY  CHEST_PAIN LUNG_CANCER
# ...

# %%
data.isnull().sum()
# Out:
# GENDER                   0
# AGE                      0
# SMOKING                  0
# YELLOW_FINGERS           0
# ANXIETY                  0
# PEER_PRESSURE            0
# CHRONIC_DISEASE          0
# FATIGUE                  0
# ALLERGY                  0
# WHEEZING                 0
# ALCOHOL_CONSUMING        0
# COUGHING                 0
# SHORTNESS_OF_BREATH      0
# SWALLOWING_DIFFICULTY    0
# CHEST_PAIN               0
# LUNG_CANCER              0
# dtype: int64

# %%
data["GENDER"].fillna(data["GENDER"].mode()[0], inplace=True)

# %%
data["LUNG_CANCER"].fillna(data["LUNG_CANCER"].mode()[0], inplace=True)

# %%
#one hot encoding: 1. get dummies 2. one hot encoder in sklearn
en_data=data[["GENDER", "LUNG_CANCER"]]
en_data
# Out:
#      GENDER LUNG_CANCER
# 0         M          NO
# 1         F          NO
# 2         F         YES
# 3         M         YES
# 4         F          NO
# ...     ...         ...
# 2995      F          NO
# 2996      F          NO
# 2997      F         YES
# 2998      M         YES
# 2999      M         YES
#
# [3000 rows x 2 columns]

# %%
pd.get_dummies(en_data)
# Out:
#       GENDER_F  GENDER_M  LUNG_CANCER_NO  LUNG_CANCER_YES
# 0        False      True            True            False
# 1         True     False            True            False
# 2         True     False           False             True
# 3        False      True           False             True
# 4         True     False            True            False
# ...        ...       ...             ...              ...
# 2995      True     False            True            False
# 2996      True     False            True            False
# 2997      True     False           False             True
# 2998     False      True           False             True
# 2999     False      True           False             True
#
# [3000 rows x 4 columns]

# %%
pd.get_dummies(en_data).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   GENDER_F         3000 non-null   bool
#  1   GENDER_M         3000 non-null   bool
#  2   LUNG_CANCER_NO   3000 non-null   bool
#  3   LUNG_CANCER_YES  3000 non-null   bool
# dtypes: bool(4)
# memory usage: 11.8 KB

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
ohe=OneHotEncoder()
ohe.fit_transform(en_data)
# Out:
# <3000x4 sparse matrix of type '<class 'numpy.float64'>'
# 	with 6000 stored elements in Compressed Sparse Row format>

# %%
ohe=OneHotEncoder()
ar=ohe.fit_transform(en_data).toarray()

# %%
pd.DataFrame(ar,columns=["GENDER_F", "GENDER_M", "LUNG_CANCER_NO", "LUNG_CANCER_YES"])
# Out:
#       GENDER_F  GENDER_M  LUNG_CANCER_NO  LUNG_CANCER_YES
# 0          0.0       1.0             1.0              0.0
# 1          1.0       0.0             1.0              0.0
# 2          1.0       0.0             0.0              1.0
# 3          0.0       1.0             0.0              1.0
# 4          1.0       0.0             1.0              0.0
# ...        ...       ...             ...              ...
# 2995       1.0       0.0             1.0              0.0
# 2996       1.0       0.0             1.0              0.0
# 2997       1.0       0.0             0.0              1.0
# 2998       0.0       1.0             0.0              1.0
# 2999       0.0       1.0             0.0              1.0
#
# [3000 rows x 4 columns]

# %%
ohe=OneHotEncoder(drop="first")
ar=ohe.fit_transform(en_data).toarray()

# %%
pd.DataFrame(ar,columns=[ "GENDER_M", "LUNG_CANCER_YES"])
# Out:
#       GENDER_M  LUNG_CANCER_YES
# 0          1.0              0.0
# 1          0.0              0.0
# 2          0.0              1.0
# 3          1.0              1.0
# 4          0.0              0.0
# ...        ...              ...
# 2995       0.0              0.0
# 2996       0.0              0.0
# 2997       0.0              1.0
# 2998       1.0              1.0
# 2999       1.0              1.0
#
# [3000 rows x 2 columns]
