# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
data=pd.read_csv(r"C:\Users\HP\Desktop\Cyber crime2019.csv")
data.head()
# Out:
#    S. No                                         Crime Head  \
# 0      1                Tampering computer source documents
# 1  2.1.1              Ransom-ware Computer Related Offences
# 2  2.1.2  Offences other than Ransom-ware Computer Relat...
# 3    2.2  Dishonestly receiving stolen computer resource...
# 4    2.3                                     Identity Theft
#
#    Cases Pending Investi-gation from Previous Year  \
# 0                                              165
# 1                                              995
# 2                                             2732
# 3                                              396
# 4                                             8634
#
#    Cases Reported during the year  Cases Reopened for Investi-gation  \
# 0                           173.0                                  0
# 1                          1023.0                                  0
# 2                          3444.0                                  0
# ...

# %%
data.head(10)
# Out:
#    S. No                                         Crime Head  \
# 0      1                Tampering computer source documents
# 1  2.1.1              Ransom-ware Computer Related Offences
# 2  2.1.2  Offences other than Ransom-ware Computer Relat...
# 3    2.2  Dishonestly receiving stolen computer resource...
# 4    2.3                                     Identity Theft
# 5    2.4  Cheating by personation by using computer reso...
# 6    2.5                               Violation of Privacy
# 7      3                                    Cyber Terrorism
# 8    4.1  Publishing or transmitting obscene material in...
# 9    4.2  Publishing or transmitting of material contain...
#
#    Cases Pending Investi-gation from Previous Year  \
# 0                                              165
# 1                                              995
# 2                                             2732
# 3                                              396
# ...

# %%
data.isnull()
# Out:
#     S. No  Crime Head  Cases Pending Investi-gation from Previous Year  \
# 0   False       False                                            False
# 1   False       False                                            False
# 2   False       False                                            False
# 3   False       False                                            False
# 4   False       False                                            False
# 5   False       False                                            False
# 6   False       False                                            False
# 7   False       False                                            False
# 8   False       False                                            False
# 9   False       False                                            False
# 10  False       False                                            False
# 11  False       False                                            False
# ...

# %%
data.isnull().sum()
# Out:
# S. No                                                                            0
# Crime Head                                                                       0
# Cases Pending Investi-gation from Previous Year                                  0
# Cases Reported during the year                                                   1
# Cases Reopened for Investi-gation                                                0
# Total Cases for Investi-gation (Col.3+ Col.4+ Col.5)                             3
# Cases Not Investi-gated Under 157_1_b CRPC                                       1
# Cases Transferred to other State or Agency                                       0
# Cases With-drawn by the Govt during investi-gation                               1
# Final Report -  Cases Ended as FR Non Cognizable                                 0
# Final Report -  Cases Ended as Final Report False                                1
# ...

# %%
data.isnull().sum().sum()
# Out:
# 11

# %%
(data.isnull().sum().sum()/data.shape[0])*100
# Out:
# 27.500000000000004

# %%
(data.isnull().sum().sum()/data.shape[0]*data.shape[1])*100
# Out:
# 660.0

# %%
data.notnull().sum()
# Out:
# S. No                                                                            40
# Crime Head                                                                       40
# Cases Pending Investi-gation from Previous Year                                  40
# Cases Reported during the year                                                   39
# Cases Reopened for Investi-gation                                                40
# Total Cases for Investi-gation (Col.3+ Col.4+ Col.5)                             37
# Cases Not Investi-gated Under 157_1_b CRPC                                       39
# Cases Transferred to other State or Agency                                       40
# Cases With-drawn by the Govt during investi-gation                               39
# Final Report -  Cases Ended as FR Non Cognizable                                 40
# Final Report -  Cases Ended as Final Report False                                39
# ...

# %%
sns.heatmap(data.isnull())
plt.show()

# %%
data.drop(columns=["Chargesheets submitted -  Cases Chargesheeted Out of Cases from Previous Year"], inplace=True)

# %%
data.isnull().sum()
# Out:
# S. No                                                                            0
# Crime Head                                                                       0
# Cases Pending Investi-gation from Previous Year                                  0
# Cases Reported during the year                                                   1
# Cases Reopened for Investi-gation                                                0
# Total Cases for Investi-gation (Col.3+ Col.4+ Col.5)                             3
# Cases Not Investi-gated Under 157_1_b CRPC                                       1
# Cases Transferred to other State or Agency                                       0
# Cases With-drawn by the Govt during investi-gation                               1
# Final Report -  Cases Ended as FR Non Cognizable                                 0
# Final Report -  Cases Ended as Final Report False                                1
# ...

# %%
data.dropna(inplace=True)

# %%
sns.heatmap(data.isnull())
plt.show()

# %%
data.fillna(3).head(10)
# Out:
#     S. No                                         Crime Head  \
# 1   2.1.1              Ransom-ware Computer Related Offences
# 3     2.2  Dishonestly receiving stolen computer resource...
# 4     2.3                                     Identity Theft
# 5     2.4  Cheating by personation by using computer reso...
# 8     4.1  Publishing or transmitting obscene material in...
# 10    4.3  Publishing or transmitting of material depicti...
# 13      5  Interception or Monitoring or decryption of In...
# 14      6  Un-authorized access/attempt to  access to pro...
# 16      8                         Attempt to Commit Offences
# 17      9                           Other Sections of IT Act
#
#     Cases Pending Investi-gation from Previous Year  \
# 1                                               995
# 3                                               396
# 4                                              8634
# 5                                              2572
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32 entries, 1 to 39
# Data columns (total 23 columns):
#  #   Column                                                                         Non-Null Count  Dtype
# ---  ------                                                                         --------------  -----
#  0   S. No                                                                          32 non-null     object
#  1   Crime Head                                                                     32 non-null     object
#  2   Cases Pending Investi-gation from Previous Year                                32 non-null     int64
#  3   Cases Reported during the year                                                 32 non-null     float64
#  4   Cases Reopened for Investi-gation                                              32 non-null     int64
#  5   Total Cases for Investi-gation (Col.3+ Col.4+ Col.5)                           32 non-null     float64
# ...

# %%
data.fillna(method="bfill")
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_12068\1981131366.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data.fillna(method="bfill")
#     S. No                                         Crime Head  \
# 1   2.1.1              Ransom-ware Computer Related Offences
# 3     2.2  Dishonestly receiving stolen computer resource...
# 4     2.3                                     Identity Theft
# 5     2.4  Cheating by personation by using computer reso...
# 8     4.1  Publishing or transmitting obscene material in...
# 10    4.3  Publishing or transmitting of material depicti...
# 13      5  Interception or Monitoring or decryption of In...
# 14      6  Un-authorized access/attempt to  access to pro...
# 16      8                         Attempt to Commit Offences
# 17      9                           Other Sections of IT Act
# 18     11                       Abetment of Suicide (Online)
# ...

# %%
data.fillna(method="ffill")
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_12068\2321864255.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data.fillna(method="ffill")
#     S. No                                         Crime Head  \
# 1   2.1.1              Ransom-ware Computer Related Offences
# 3     2.2  Dishonestly receiving stolen computer resource...
# 4     2.3                                     Identity Theft
# 5     2.4  Cheating by personation by using computer reso...
# 8     4.1  Publishing or transmitting obscene material in...
# 10    4.3  Publishing or transmitting of material depicti...
# 13      5  Interception or Monitoring or decryption of In...
# 14      6  Un-authorized access/attempt to  access to pro...
# 16      8                         Attempt to Commit Offences
# 17      9                           Other Sections of IT Act
# 18     11                       Abetment of Suicide (Online)
# ...

# %%
data.fillna(method="ffill", axis=1)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_12068\482118045.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data.fillna(method="ffill", axis=1)
#     S. No                                         Crime Head  \
# 1   2.1.1              Ransom-ware Computer Related Offences
# 3     2.2  Dishonestly receiving stolen computer resource...
# 4     2.3                                     Identity Theft
# 5     2.4  Cheating by personation by using computer reso...
# 8     4.1  Publishing or transmitting obscene material in...
# 10    4.3  Publishing or transmitting of material depicti...
# 13      5  Interception or Monitoring or decryption of In...
# 14      6  Un-authorized access/attempt to  access to pro...
# 16      8                         Attempt to Commit Offences
# 17      9                           Other Sections of IT Act
# 18     11                       Abetment of Suicide (Online)
# ...

# %%
data.select_dtypes(include="object")
# Out:
#     S. No                                         Crime Head
# 1   2.1.1              Ransom-ware Computer Related Offences
# 3     2.2  Dishonestly receiving stolen computer resource...
# 4     2.3                                     Identity Theft
# 5     2.4  Cheating by personation by using computer reso...
# 8     4.1  Publishing or transmitting obscene material in...
# 10    4.3  Publishing or transmitting of material depicti...
# 13      5  Interception or Monitoring or decryption of In...
# 14      6  Un-authorized access/attempt to  access to pro...
# 16      8                         Attempt to Commit Offences
# 17      9                           Other Sections of IT Act
# 18     11                       Abetment of Suicide (Online)
# 19     12          Cyber Stalking/Bullying of Women/Children
# 20     13                                         Data theft
# 21   14.1                       Credit Card/Debit Card fraud
# ...

# %%
data.select_dtypes(include="object").isnull().sum()
# Out:
# S. No         0
# Crime Head    0
# dtype: int64

# %%
for i in data.select_dtypes(include="object").columns:
    print (i)
# Out:
# S. No
# Crime Head
