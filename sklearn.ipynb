# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
data=pd.read_csv(r"C:\Users\HP\Desktop\Cyber crime2019.csv")
data.head()
# Out:
#    S. No                                         Crime Head  \
# 0      1                Tampering computer source documents
# 1  2.1.1              Ransom-ware Computer Related Offences
# 2  2.1.2  Offences other than Ransom-ware Computer Relat...
# 3    2.2  Dishonestly receiving stolen computer resource...
# 4    2.3                                     Identity Theft
#
#    Cases Pending Investi-gation from Previous Year  \
# 0                                              165
# 1                                              995
# 2                                             2732
# 3                                              396
# 4                                             8634
#
#    Cases Reported during the year  Cases Reopened for Investi-gation  \
# 0                           173.0                                  0
# 1                          1023.0                                  0
# 2                          3444.0                                  0
# ...

# %%
data.isnull().sum()
# Out:
# S. No                                                                            0
# Crime Head                                                                       0
# Cases Pending Investi-gation from Previous Year                                  0
# Cases Reported during the year                                                   1
# Cases Reopened for Investi-gation                                                0
# Total Cases for Investi-gation (Col.3+ Col.4+ Col.5)                             3
# Cases Not Investi-gated Under 157_1_b CRPC                                       1
# Cases Transferred to other State or Agency                                       0
# Cases With-drawn by the Govt during investi-gation                               1
# Final Report -  Cases Ended as FR Non Cognizable                                 0
# Final Report -  Cases Ended as Final Report False                                1
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 24 columns):
#  #   Column                                                                         Non-Null Count  Dtype
# ---  ------                                                                         --------------  -----
#  0   S. No                                                                          40 non-null     object
#  1   Crime Head                                                                     40 non-null     object
#  2   Cases Pending Investi-gation from Previous Year                                40 non-null     int64
#  3   Cases Reported during the year                                                 39 non-null     float64
#  4   Cases Reopened for Investi-gation                                              40 non-null     int64
#  5   Total Cases for Investi-gation (Col.3+ Col.4+ Col.5)                           37 non-null     float64
# ...

# %%
data.select_dtypes(include="float64").columns
# Out:
# Index(['Cases Reported during the year',
#        'Total Cases for Investi-gation (Col.3+ Col.4+ Col.5)',
#        'Cases Not Investi-gated Under 157_1_b CRPC',
#        'Cases With-drawn by the Govt during investi-gation',
#        'Final Report -  Cases Ended as Final Report False',
#        'Final Report -  Total (Col.10+ Col.11+ Col.12+ Col.13+ Col.14)',
#        'Chargesheets submitted -  Cases Chargesheeted Out of Cases from Previous Year',
#        'Charge-Sheeting Rate (Col.18/ Col.19) *100',
#        'Pen- dency Percent age (Col.22/ Col.6) *100'],
#       dtype='object')

# %%
from sklearn.impute import SimpleImputer

# %%
si=SimpleImputer(strategy="mean")
ar=si.fit_transform(data[['Cases Reported during the year',
       'Total Cases for Investi-gation (Col.3+ Col.4+ Col.5)',
       'Cases Not Investi-gated Under 157_1_b CRPC',
       'Cases With-drawn by the Govt during investi-gation',
       'Final Report -  Cases Ended as Final Report False',
       'Final Report -  Total (Col.10+ Col.11+ Col.12+ Col.13+ Col.14)',
       'Chargesheets submitted -  Cases Chargesheeted Out of Cases from Previous Year',
       'Charge-Sheeting Rate (Col.18/ Col.19) *100',
       'Pen- dency Percent age (Col.22/ Col.6) *100']])

# %%
pd.DataFrame(ar,columns=data.select_dtypes(include="float64").columns)
# Out:
#     Cases Reported during the year  \
# 0                       173.000000
# 1                      1023.000000
# 2                      3444.000000
# 3                       558.000000
# 4                     12255.000000
# 5                      5520.000000
# 6                       812.000000
# 7                        12.000000
# 8                      1845.000000
# 9                      1106.461538
# 10                      102.000000
# 11                       14.000000
# 12                      832.000000
# 13                        9.000000
# 14                        2.000000
# 15                        0.000000
# 16                       14.000000
# 17                     2720.000000
# 18                        8.000000
# 19                      777.000000
# 20                      285.000000
# 21                      367.000000
# 22                     2067.000000
# 23                     2093.000000
# 24                      549.000000
# ...

# %%
new_data=pd.DataFrame(ar,columns=data.select_dtypes(include="float64").columns)

# %%
new_data.isnull().sum()
# Out:
# Cases Reported during the year                                                   0
# Total Cases for Investi-gation (Col.3+ Col.4+ Col.5)                             0
# Cases Not Investi-gated Under 157_1_b CRPC                                       0
# Cases With-drawn by the Govt during investi-gation                               0
# Final Report -  Cases Ended as Final Report False                                0
# Final Report -  Total (Col.10+ Col.11+ Col.12+ Col.13+ Col.14)                   0
# Chargesheets submitted -  Cases Chargesheeted Out of Cases from Previous Year    0
# Charge-Sheeting Rate (Col.18/ Col.19) *100                                       0
# Pen- dency Percent age (Col.22/ Col.6) *100                                      0
# dtype: int64

# %%
new_data
# Out:
#     Cases Reported during the year  \
# 0                       173.000000
# 1                      1023.000000
# 2                      3444.000000
# 3                       558.000000
# 4                     12255.000000
# 5                      5520.000000
# 6                       812.000000
# 7                        12.000000
# 8                      1845.000000
# 9                      1106.461538
# 10                      102.000000
# 11                       14.000000
# 12                      832.000000
# 13                        9.000000
# 14                        2.000000
# 15                        0.000000
# 16                       14.000000
# 17                     2720.000000
# 18                        8.000000
# 19                      777.000000
# 20                      285.000000
# 21                      367.000000
# 22                     2067.000000
# 23                     2093.000000
# 24                      549.000000
# ...
